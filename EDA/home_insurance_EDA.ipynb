# %%
import numpy as np
import pandas as pd
from pandas_profiling import ProfileReport
import random

random.seed(42)

# %%
df = pd.read_csv("../Data/Raw_data/home_insurance.csv")
df.head(10)
# Out:
#    QUOTE_DATE COVER_START CLAIM3YEARS P1_EMP_STATUS P1_PT_EMP_STATUS BUS_USE  \
# 0  11/22/2007  22/11/2007           N             R              NaN       N
# 1  11/22/2007  01/01/2008           N             E              NaN       Y
# 2  11/23/2007  23/11/2007           N             E              NaN       N
# 3  11/23/2007  12/12/2007           N             R              NaN       N
# 4  11/22/2007  15/12/2007           N             R              NaN       N
# 5  11/22/2007  01/12/2007           N             R              NaN       N
# 6  11/19/2007  12/12/2007           N             R              NaN       N
# 7  11/22/2007  01/12/2007           N             R              NaN       N
# 8  11/22/2007  01/02/2008           N             E              NaN       N
# 9  11/22/2007  01/12/2007           N             E              NaN       N
#
#   CLERICAL AD_BUILDINGS  RISK_RATED_AREA_B  SUM_INSURED_BUILDINGS  ...  \
# ...

# %%
df_1 = df.sample(frac=0.1, random_state=1)
df_1.head()
# Out:
#         QUOTE_DATE COVER_START CLAIM3YEARS P1_EMP_STATUS P1_PT_EMP_STATUS  \
# 13930          NaN  10/12/2007           N             E              NaN
# 242391  12/28/2011         NaN         NaN           NaN              NaN
# 127998   9/29/2011         NaN         NaN           NaN              NaN
# 120458         NaN         NaN         NaN           NaN              NaN
# 60515   11/17/2007  01/12/2007           N             E              NaN
#
#        BUS_USE CLERICAL AD_BUILDINGS  RISK_RATED_AREA_B  \
# 13930        N      NaN            Y                3.0
# 242391     NaN      NaN          NaN                NaN
# 127998     NaN      NaN          NaN                NaN
# 120458     NaN      NaN          NaN                NaN
# 60515        N      NaN            Y                NaN
#
#         SUM_INSURED_BUILDINGS  ...  HP3_ADDON_PRE_REN HP3_ADDON_POST_REN  \
# 13930               1000000.0  ...                  N                  N
# ...

# %%
df_2 = df.sample(frac=0.01, random_state=1)
profile = ProfileReport(df_2, title="Home Insurance Data Report")
profile.to_file("home_insurance_report.html")
# Out:
# Summarize dataset:   0%|          | 0/80 [00:00<?, ?it/s]
